# %%
import tensorflow as tf
W = tf.Variable(tf.random_normal([1]), name='weight') 
b = tf.Variable(tf.random_normal([1]), name='bias') 
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None]) 
# Our hypothesis XW+b 
hypothesis = X * W + b 
# cost/loss function 
cost = tf.reduce_mean(tf.square(hypothesis - Y)) 
# Minimize 
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost) 
# Launch the graph in a session. 
sess = tf.Session() 
# Initializes global variables in the graph. 
sess.run(tf.global_variables_initializer()) 
# Fit the line 
for step in range(2001): 
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], feed_dict={X: [1, 2, 3], Y: [1, 2, 3]})
    if step % 20 == 0: 
        print(step, cost_val, W_val, b_val)
# Out:
# (0, 2.5294063, array([ 1.1812067], dtype=float32), array([ 1.0507412], dtype=float32))
# (20, 0.10872614, array([ 0.71025449], dtype=float32), array([ 0.79793376], dtype=float32))
# (40, 0.078904159, array([ 0.67983854], dtype=float32), array([ 0.74106377], dtype=float32))
# (60, 0.071482174, array([ 0.69069213], dtype=float32), array([ 0.70439214], dtype=float32))
# (80, 0.064919583, array([ 0.70482928], dtype=float32), array([ 0.6711126], dtype=float32))
# (100, 0.058960948, array([ 0.71866322], dtype=float32), array([ 0.63955605], dtype=float32))
# (120, 0.05354932, array([ 0.73188144], dtype=float32), array([ 0.60949773], dtype=float32))
# (140, 0.048634339, array([ 0.74448162], dtype=float32), array([ 0.58085346], dtype=float32))
# (160, 0.044170514, array([ 0.75648999], dtype=float32), array([ 0.55355555], dtype=float32))
# (180, 0.040116373, array([ 0.76793408], dtype=float32), array([ 0.52754033], dtype=float32))
# (200, 0.036434334, array([ 0.7788403], dtype=float32), array([ 0.50274801], dtype=float32))
# (220, 0.033090219, array([ 0.78923398], dtype=float32), array([ 0.47912073], dtype=float32))
# (240, 0.030053088, array([ 0.7991392], dtype=float32), array([ 0.45660383], dtype=float32))
# (260, 0.027294694, array([ 0.80857891], dtype=float32), array([ 0.43514514], dtype=float32))
# (280, 0.024789447, array([ 0.81757504], dtype=float32), array([ 0.41469488], dtype=float32))
# (300, 0.022514192, array([ 0.82614827], dtype=float32), array([ 0.39520577], dtype=float32))
# (320, 0.020447781, array([ 0.83431864], dtype=float32), array([ 0.3766326], dtype=float32))
# (340, 0.018571006, array([ 0.84210503], dtype=float32), array([ 0.35893238], dtype=float32))
# (360, 0.016866483, array([ 0.84952551], dtype=float32), array([ 0.34206387], dtype=float32))
# (380, 0.015318401, array([ 0.8565973], dtype=float32), array([ 0.32598811], dtype=float32))
# (400, 0.013912416, array([ 0.86333668], dtype=float32), array([ 0.31066778], dtype=float32))
# (420, 0.012635465, array([ 0.86975944], dtype=float32), array([ 0.29606754], dtype=float32))
# (440, 0.011475727, array([ 0.87588018], dtype=float32), array([ 0.2821534], dtype=float32))
# (460, 0.010422441, array([ 0.88171333], dtype=float32), array([ 0.2688933], dtype=float32))
# (480, 0.009465836, array([ 0.8872723], dtype=float32), array([ 0.25625631], dtype=float32))
# (500, 0.0085970191, array([ 0.8925702], dtype=float32), array([ 0.24421319], dtype=float32))
# (520, 0.0078079551, array([ 0.89761895], dtype=float32), array([ 0.2327361], dtype=float32))
# (540, 0.007091315, array([ 0.90243053], dtype=float32), array([ 0.22179839], dtype=float32))
# (560, 0.0064404397, array([ 0.90701586], dtype=float32), array([ 0.21137466], dtype=float32))
# (580, 0.0058493284, array([ 0.91138583], dtype=float32), array([ 0.20144087], dtype=float32))
# (600, 0.0053124409, array([ 0.91555035], dtype=float32), array([ 0.19197385], dtype=float32))
# (620, 0.0048248456, array([ 0.91951919], dtype=float32), array([ 0.18295182], dtype=float32))
# (640, 0.0043820008, array([ 0.92330146], dtype=float32), array([ 0.17435373], dtype=float32))
# (660, 0.003979804, array([ 0.92690605], dtype=float32), array([ 0.16615976], dtype=float32))
# (680, 0.003614519, array([ 0.93034124], dtype=float32), array([ 0.15835081], dtype=float32))
# (700, 0.003282761, array([ 0.93361491], dtype=float32), array([ 0.15090887], dtype=float32))
# (720, 0.0029814595, array([ 0.93673474], dtype=float32), array([ 0.14381675], dtype=float32))
# (740, 0.0027078066, array([ 0.93970793], dtype=float32), array([ 0.13705789], dtype=float32))
# (760, 0.0024592802, array([ 0.94254148], dtype=float32), array([ 0.13061671], dtype=float32))
# (780, 0.0022335567, array([ 0.94524181], dtype=float32), array([ 0.12447819], dtype=float32))
# (800, 0.0020285468, array([ 0.9478153], dtype=float32), array([ 0.11862815], dtype=float32))
# (820, 0.0018423641, array([ 0.95026785], dtype=float32), array([ 0.11305302], dtype=float32))
# (840, 0.0016732599, array([ 0.95260501], dtype=float32), array([ 0.10773993], dtype=float32))
# (860, 0.0015196829, array([ 0.95483243], dtype=float32), array([ 0.10267653], dtype=float32))
# (880, 0.0013802008, array([ 0.95695513], dtype=float32), array([ 0.09785109], dtype=float32))
# (900, 0.0012535149, array([ 0.95897812], dtype=float32), array([ 0.09325244], dtype=float32))
# (920, 0.0011384659, array([ 0.96090603], dtype=float32), array([ 0.08886988], dtype=float32))
# (940, 0.0010339738, array([ 0.96274328], dtype=float32), array([ 0.08469331], dtype=float32))
# (960, 0.00093906856, array([ 0.96449417], dtype=float32), array([ 0.08071304], dtype=float32))
# (980, 0.00085287797, array([ 0.96616286], dtype=float32), array([ 0.07691981], dtype=float32))
# (1000, 0.00077459245, array([ 0.96775305], dtype=float32), array([ 0.07330485], dtype=float32))
# (1020, 0.00070350105, array([ 0.9692685], dtype=float32), array([ 0.06985983], dtype=float32))
# (1040, 0.00063892873, array([ 0.9707129], dtype=float32), array([ 0.06657664], dtype=float32))
# (1060, 0.00058028713, array([ 0.97208923], dtype=float32), array([ 0.06344777], dtype=float32))
# (1080, 0.00052702514, array([ 0.97340095], dtype=float32), array([ 0.06046595], dtype=float32))
# (1100, 0.00047865382, array([ 0.97465098], dtype=float32), array([ 0.05762427], dtype=float32))
# (1120, 0.00043472034, array([ 0.9758423], dtype=float32), array([ 0.05491616], dtype=float32))
# (1140, 0.00039482108, array([ 0.97697759], dtype=float32), array([ 0.05233531], dtype=float32))
# (1160, 0.00035858303, array([ 0.97805953], dtype=float32), array([ 0.04987575], dtype=float32))
# (1180, 0.00032566884, array([ 0.97909063], dtype=float32), array([ 0.04753179], dtype=float32))
# (1200, 0.00029577906, array([ 0.98007333], dtype=float32), array([ 0.04529804], dtype=float32))
# (1220, 0.00026863292, array([ 0.98100984], dtype=float32), array([ 0.04316917], dtype=float32))
# (1240, 0.00024397731, array([ 0.9819023], dtype=float32), array([ 0.04114037], dtype=float32))
# (1260, 0.00022158417, array([ 0.9827528], dtype=float32), array([ 0.03920692], dtype=float32))
# (1280, 0.00020124381, array([ 0.98356342], dtype=float32), array([ 0.03736432], dtype=float32))
# (1300, 0.00018277419, array([ 0.98433578], dtype=float32), array([ 0.03560832], dtype=float32))
# (1320, 0.0001659984, array([ 0.98507196], dtype=float32), array([ 0.03393489], dtype=float32))
# (1340, 0.00015076221, array([ 0.9857735], dtype=float32), array([ 0.03234009], dtype=float32))
# (1360, 0.00013692492, array([ 0.98644209], dtype=float32), array([ 0.03082026], dtype=float32))
# (1380, 0.00012435706, array([ 0.98707926], dtype=float32), array([ 0.02937182], dtype=float32))
# (1400, 0.00011294286, array([ 0.98768651], dtype=float32), array([ 0.02799147], dtype=float32))
# (1420, 0.00010257616, array([ 0.98826522], dtype=float32), array([ 0.02667596], dtype=float32))
# (1440, 9.316198e-05, array([ 0.98881662], dtype=float32), array([ 0.0254223], dtype=float32))
# (1460, 8.4611056e-05, array([ 0.98934221], dtype=float32), array([ 0.02422757], dtype=float32))
# (1480, 7.6845252e-05, array([ 0.98984319], dtype=float32), array([ 0.02308894], dtype=float32))
# (1500, 6.9791284e-05, array([ 0.99032056], dtype=float32), array([ 0.02200375], dtype=float32))
# (1520, 6.3386113e-05, array([ 0.99077547], dtype=float32), array([ 0.02096964], dtype=float32))
# (1540, 5.7568122e-05, array([ 0.99120897], dtype=float32), array([ 0.01998411], dtype=float32))
# (1560, 5.2283995e-05, array([ 0.99162209], dtype=float32), array([ 0.01904491], dtype=float32))
# (1580, 4.7485708e-05, array([ 0.9920159], dtype=float32), array([ 0.01814987], dtype=float32))
# (1600, 4.3126409e-05, array([ 0.99239111], dtype=float32), array([ 0.01729687], dtype=float32))
# (1620, 3.9168437e-05, array([ 0.99274874], dtype=float32), array([ 0.01648395], dtype=float32))
# (1640, 3.5573223e-05, array([ 0.99308944], dtype=float32), array([ 0.01570926], dtype=float32))
# (1660, 3.2308566e-05, array([ 0.99341422], dtype=float32), array([ 0.01497101], dtype=float32))
# (1680, 2.9342676e-05, array([ 0.99372375], dtype=float32), array([ 0.01426743], dtype=float32))
# (1700, 2.6648937e-05, array([ 0.99401873], dtype=float32), array([ 0.01359689], dtype=float32))
# (1720, 2.4203886e-05, array([ 0.99429977], dtype=float32), array([ 0.0129579], dtype=float32))
# (1740, 2.1981556e-05, array([ 0.99456769], dtype=float32), array([ 0.01234893], dtype=float32))
# (1760, 1.9964873e-05, array([ 0.99482292], dtype=float32), array([ 0.01176859], dtype=float32))
# (1780, 1.8131943e-05, array([ 0.99506623], dtype=float32), array([ 0.01121556], dtype=float32))
# (1800, 1.646794e-05, array([ 0.99529815], dtype=float32), array([ 0.01068845], dtype=float32))
# (1820, 1.4955913e-05, array([ 0.9955191], dtype=float32), array([ 0.01018612], dtype=float32))
# (1840, 1.3583533e-05, array([ 0.99572968], dtype=float32), array([ 0.00970742], dtype=float32))
# (1860, 1.2337252e-05, array([ 0.99593037], dtype=float32), array([ 0.00925121], dtype=float32))
# (1880, 1.1204465e-05, array([ 0.99612164], dtype=float32), array([ 0.00881644], dtype=float32))
# (1900, 1.0175846e-05, array([ 0.99630392], dtype=float32), array([ 0.0084021], dtype=float32))
# (1920, 9.2417467e-06, array([ 0.9964776], dtype=float32), array([ 0.00800722], dtype=float32))
# (1940, 8.3937966e-06, array([ 0.99664313], dtype=float32), array([ 0.00763093], dtype=float32))
# (1960, 7.6234414e-06, array([ 0.9968009], dtype=float32), array([ 0.00727231], dtype=float32))
# (1980, 6.9237285e-06, array([ 0.99695122], dtype=float32), array([ 0.00693055], dtype=float32))
# (2000, 6.2882555e-06, array([ 0.99709451], dtype=float32), array([ 0.00660484], dtype=float32))
